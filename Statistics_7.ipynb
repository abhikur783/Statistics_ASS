# %%
Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
of 5 using Python. Interpret the results.
Ans:
    import scipy.stats as stats

mean = 50
std_dev = 5
sample_size = # Insert the size of your sample here

confidence_interval = stats.norm.interval(0.95, loc=mean, scale=std_dev / (sample_size ** 0.5))

print("95% Confidence Interval:", confidence_interval)

# %%
Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag
matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20%
brown. Use Python to perform the test with a significance level of 0.05.
Ans:
    import numpy as np
import scipy.stats as stats

# Observed frequencies of each color in the sample
observed_frequencies = np.array([blue_freq, orange_freq, green_freq, yellow_freq, red_freq, brown_freq])

# Expected frequencies based on the given distribution
expected_frequencies = np.array([0.20, 0.20, 0.20, 0.10, 0.10, 0.20]) * total_sample_size

# Perform the chi-square test
chi2, p_value = stats.chisquare(observed_frequencies, f_exp=expected_frequencies)

# Compare p-value with the significance level (0.05 in this case)
significance_level = 0.05

if p_value < significance_level:
    print("Reject the null hypothesis. The distribution of colors of M&Ms does not match the expected distribution.")
else:
    print("Fail to reject the null hypothesis. The distribution of colors of M&Ms matches the expected distribution.")

# %%
Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals
smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the
population who smoke.
Ans:
    import statsmodels.api as sm

sample_size = 500
smokers_count = 60

# Calculate the proportion of smokers in the sample
sample_proportion = smokers_count / sample_size

# Calculate the standard error
standard_error = (sample_proportion * (1 - sample_proportion) / sample_size) ** 0.5

# Calculate the 95% confidence interval using the z-score (for large sample size)
confidence_interval = sm.stats.proportion_confint(smokers_count, sample_size, alpha=0.05, method='normal')

print("95% Confidence Interval:", confidence_interval)

# %%
Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation
of 12 using Python. Interpret the results.
Ans:
    import scipy.stats as stats

mean = 75
std_dev = 12
sample_size = # Insert the size of your sample here

confidence_interval = stats.norm.interval(0.90, loc=mean, scale=std_dev / (sample_size ** 0.5))

print("90% Confidence Interval:", confidence_interval)

# %%
Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the
area corresponding to a chi-square statistic of 15.
Ans:
    import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Define the degrees of freedom
df = 10

# Generate x values for the chi-square distribution
x = np.linspace(0, 30, 500)

# Calculate the corresponding probability density function (PDF)
pdf = stats.chi2.pdf(x, df)

# Plot the chi-square distribution
plt.plot(x, pdf, label=f"Chi-Square Distribution (df={df})")

# Shade the area corresponding to a chi-square statistic of 15
x_shade = np.linspace(15, 30, 100)
plt.fill_between(x_shade, stats.chi2.pdf(x_shade, df), color='blue', alpha=0.3, label="Area for chi-square stat of 15")

# Label the axes
plt.xlabel("Chi-Square Statistic")
plt.ylabel("Probability Density Function (PDF)")
plt.title("Chi-Square Distribution with 10 degrees of freedom")
plt.legend()

# Show the plot
plt.grid(True)
plt.show()

# %%
Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520
preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who
prefer Coke.
Ans:
    import statsmodels.api as sm

sample_size = 1000
coke_preferred_count = 520

# Calculate the proportion of people who prefer Coke in the sample
sample_proportion = coke_preferred_count / sample_size

# Calculate the standard error
standard_error = (sample_proportion * (1 - sample_proportion) / sample_size) ** 0.5

# Calculate the 99% confidence interval using the z-score (for large sample size)
confidence_interval = sm.stats.proportion_confint(coke_preferred_count, sample_size, alpha=0.01, method='normal')

print("99% Confidence Interval:", confidence_interval)

# %%
Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe
45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the
expected frequencies of a fair coin. Use a significance level of 0.05.
Ans:
    import numpy as np
import scipy.stats as stats

# Observed frequencies
observed_tails = 45
total_flips = 100

# Expected frequencies for a fair coin
expected_tails = total_flips * 0.5

# Calculate the observed and expected frequencies as an array
observed_frequencies = np.array([observed_tails, total_flips - observed_tails])
expected_frequencies = np.array([expected_tails, total_flips - expected_tails])

# Perform the chi-square test
chi2, p_value = stats.chisquare(observed_frequencies, f_exp=expected_frequencies)

# Compare p-value with the significance level (0.05 in this case)
significance_level = 0.05

if p_value < significance_level:
    print("Reject the null hypothesis. The coin is biased towards tails.")
else:
    print("Fail to reject the null hypothesis. There is no evidence that the coin is biased towards tails.")

# %%
Q11. A random sample of 30 people was selected from a population with an unknown mean and standard
deviation. The sample mean was found to be 72 and the sample standard deviation was found to be 10.
Conduct a hypothesis test to determine if the population mean is significantly different from 70. Use a
significance level of 0.05.
